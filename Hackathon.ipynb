# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
dat=pd.read_excel('C:/Users/admin/Downloads/DDWCT-0000C-08A.xlsx', header=1)
dat.head(50)
# Out:
#    table name  state code   town code              town name  rural/urban  \
# 0      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 1      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 2      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 3      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 4      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 5      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 6      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 7      C2408A            1     800013   Srinagar (M Corp.+OG)       Urban
# 8      C2408A            1     800033      Anantnag (M Cl+OG)       Urban
# 9      C2408A            1     800033      Anantnag (M Cl+OG)       Urban
# 10     C2408A            1     800033      Anantnag (M Cl+OG)       Urban
# 11     C2408A            1     800033      Anantnag (M Cl+OG)       Urban
# ...
